# %%
from arcgis.gis import GIS

# %%
gis = GIS(url = "https://www.arcgis.com", username = "chekos", password = "Arlette64")

# %%
_map_1 = gis.map("Hotel Murano, Tacoma, WA")
_map_1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b2eac53a-3f84-4130-9782-217c702832f0"><img src=""></img></div>

# %%
from IPython.display import display

# %%
items = gis.content.search("Tacoma", item_type="Feature Layer Collection")
for item in items:
    display(item)
# Out:
# <Item title:"Microsoft  Buildings Footprint Training Data with Heights " type:Feature Layer Collection owner:sbreyer_esri>
# <Item title:"TacPark_MainSur_RS" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>
# <Item title:"Rachel's Tacoma Park Maintanence Survey Offical_fieldworker" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>
# <Item title:"GSI_ELIGIBILITY" type:Feature Layer Collection owner:kangds_MSGT>
# <Item title:"TacPark_MainSur_2" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>
# <Item title:"Rachel's Tacoma Park Maintanence Survey Offical" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>
# <Item title:"Parks_points" type:Feature Layer Collection owner:MSGT_16_dlo27>
# <Item title:"Tacoma_PCI_2015_2016" type:Feature Layer Collection owner:esloan2@tacoma_es>
# <Item title:"WatershedAssessment_StoryMaps" type:Feature Layer Collection owner:vsimpson@tacoma_es>
# <Item title:"ncd" type:Feature Layer Collection owner:bricker0>

# %%
item_to_add = [temp_item for temp_item in items if "Park" in temp_item.title]

# %%
item_to_add
# Out:
# [<Item title:"TacPark_MainSur_RS" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>,
#  <Item title:"Rachel's Tacoma Park Maintanence Survey Offical_fieldworker" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>,
#  <Item title:"TacPark_MainSur_2" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>,
#  <Item title:"Rachel's Tacoma Park Maintanence Survey Offical" type:Feature Layer Collection owner:rs1_UWT_GIS_GeoTech>,
#  <Item title:"Parks_points" type:Feature Layer Collection owner:MSGT_16_dlo27>]

# %% [markdown]
# Changing the style

# %%
_map_1.add_layer(item_to_add[-1])

# %%
_map_1.basemaps
# Out:
# ['dark-gray',
#  'dark-gray-vector',
#  'gray',
#  'gray-vector',
#  'hybrid',
#  'national-geographic',
#  'oceans',
#  'osm',
#  'satellite',
#  'streets',
#  'streets-navigation-vector',
#  'streets-night-vector',
#  'streets-relief-vector',
#  'streets-vector',
#  'terrain',
#  'topo',
#  'topo-vector']

# %%
_map_1.basemap = 'streets'

# %% [markdown]
# Adding imagery

# %%
landsat_item = GIS().content.search("Landsat 8 Views", "Imagery Layer", max_items=2)[0]
landsat_item
# Out:
# <Item title:"Pansharpened Landsat" type:Imagery Layer owner:esri>

# %%
_map_1.add_layer(landsat_item)

# %% [markdown]
# Population

# %%
_map_1.add_layer({"type":"FeatureLayer", 
               "url":"//sampleserver6.arcgisonline.com/arcgis/rest/services/Census/MapServer/2",
               "definition_expression" : "STATE_NAME='Washington'",
               "renderer":"ClassedColorRenderer",
               "field_name":"POP2007",
               "opacity":0.7
              })
