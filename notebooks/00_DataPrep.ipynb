# %% [markdown]
# # You can find this on Backroads - Making Maps with Python NACIS 2019
# #### This repository is an exploration of mapping capabilities in the python ecosystem.
#
# <details>
#     <summary><strong>Goal</strong></summary>
#     "The goal of this notebook is to ..."
#     <ul>
#         <li> measurable goals for this notebook </li>
#         <li> Ex 1: Identify <i>variables of interest in dataset <strong>name.dta</strong></i> </li>
#         <li> Ex 2: Create a <i>working dataset</i> from raw data.</li>
#     </ul>
# </details>
#
# <details>
#     <summary><strong>Context</strong></summary>
#     Context at the moment (i.e. "We've downloaded raw data from <strong><i>website.com</i></strong> and are now in the process of creating a mastefile.")
#     <li> What is the final goal of this project?</li>
#     <li> What are we trying to recreate? Where are we in the process?</li>
#     <li> Any links to documentation / figures.</li>
# </details>

# %%
import pandas as pd
from zipfile import ZipFile
from pathlib import Path
from tools import tree
from datetime import datetime as dt
today = dt.today().strftime("%d-%b-%y")

today
# Out:
# '03-Oct-19'

# %%
RAW_DATA = Path("../data/raw/")
INTERIM_DATA = Path("../data/interim/")
PROCESSED_DATA = Path("../data/processed/")
EXTERNAL_DATA = Path("../data/external/")
FINAL_DATA = Path("../data/final/")

# %%
tree(EXTERNAL_DATA)
# Out:
# + ..\data\external
#     + Data_10-3-2019---695.csv
#     + ValueLabels_10-3-2019---695.csv

# %%
data = pd.read_csv(EXTERNAL_DATA / 'Data_10-3-2019---695.csv')

# %%
data.head()
# Out:
#    UnitID                         Institution Name  FIPS state code (HD2017)  \
# 0  177834  A T Still University of Health Sciences                        29
# 1  222178             Abilene Christian University                        48
# 2  138558     Abraham Baldwin Agricultural College                        13
# 3  488031               Abraham Lincoln University                         6
# 4  172866                          Academy College                        27
#
#    Sector of institution (HD2017)  Degree-granting status (HD2017)  \
# 0                               2                                1
# 1                               2                                1
# 2                               1                                1
# 3                               3                                1
# 4                               3                                1
#
#    Institution size category (HD2017)  \
# 0                                   2
# 1                                   3
# 2                                   2
# 3                                   1
# 4                                   1
#
#         Institution (entity) name (HD2017) Institution name alias (HD2017)  \
# 0  A T Still University of Health Sciences                             NaN
# 1             Abilene Christian University                             NaN
# 2     Abraham Baldwin Agricultural College                            ABAC
# 3               Abraham Lincoln University                             NaN
# 4                          Academy College                             NaN
#
#   Street address or post office box (HD2017)  \
# 0                            800 W Jefferson
# 1                                        NaN
# 2                             2802 Moore Hwy
# 3        3530 Wilshire Boulevard  Suite 1430
# 4             1600 W. 82nd Street  Suite 100
#
#   City location of institution (HD2017)  ...  \
# 0                            Kirksville  ...
# 1                               Abilene  ...
# 2                                Tifton  ...
# 3                           Los Angeles  ...
# 4                           Bloomington  ...
#
#   Undergraduate enrollment (DRVEF2017)  Graduate enrollment (DRVEF2017)  \
# 0                                  0.0                           3723.0
# 1                               3666.0                           1479.0
# 2                               3394.0                              0.0
# 3                                 30.0                            167.0
# 4                                 65.0                              0.0
#
#   Number of students receiving a Doctor's degree (DRVC2017)  \
# 0                                                763
# 1                                                  3
# 2                                                  0
# 3                                                 17
# 4                                                  0
#
#    Number of students receiving a Master's degree (DRVC2017)  \
# 0                                                283
# 1                                                256
# 2                                                  0
# 3                                                  6
# 4                                                  0
#
#    Number of students receiving a Bachelor's degree (DRVC2017)  \
# 0                                                  0
# 1                                                743
# 2                                                206
# 3                                                  2
# 4                                                  6
#
#    Number of students receiving an Associate's degree (DRVC2017)  \
# 0                                                  0
# 1                                                  3
# 2                                                389
# 3                                                  0
# 4                                                 16
#
#    Number of students receiving a Postbaccalaureate or Post-master's certificate (DRVC2017)  \
# 0                                                120
# 1                                                 11
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Number of students receiving a certificate of 1 but less than 4-years (DRVC2017)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  4
#
#    Number of students receiving a certificate of less than 1-year (DRVC2017)  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                 27
#
#    Unnamed: 24
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 25 columns]

# %%
col_names = data.columns.values

# %%
cols_names = [col.replace(' (HD2017)', '').replace(' (DRVC2017)', '').replace(' (DRVEF2017)', '') for col in col_names ]

# %%
cols_names
# Out:
# ['UnitID',
#  'Institution Name',
#  'FIPS state code',
#  'Sector of institution',
#  'Degree-granting status',
#  'Institution size category',
#  'Institution (entity) name',
#  'Institution name alias',
#  'Street address or post office box',
#  'City location of institution',
#  'State abbreviation',
#  'Fips County code',
#  'County name',
#  'Longitude location of institution',
#  'Latitude location of institution',
#  'Undergraduate enrollment',
#  'Graduate enrollment',
#  "Number of students receiving a Doctor's degree",
#  "Number of students receiving a Master's degree",
#  "Number of students receiving a Bachelor's degree",
#  "Number of students receiving an Associate's degree",
#  "Number of students receiving a Postbaccalaureate or Post-master's certificate",
#  'Number of students receiving a certificate of 1 but less than 4-years',
#  'Number of students receiving a certificate of less than 1-year',
#  'Unnamed: 24']

# %%
cols_clean = [
    col.replace("Doctor's degree","PhD")
    .replace("Master's degree","MA")
    .replace("Bachelor's degree","BA")
    .replace("Associate's degree","AA")
    .replace(" location of institution","")
    .replace("Number of students", "Students")
 for col in cols_names
]

# %%
data.columns = cols_clean

# %%
data.head()
# Out:
#    UnitID                         Institution Name  FIPS state code  \
# 0  177834  A T Still University of Health Sciences               29
# 1  222178             Abilene Christian University               48
# 2  138558     Abraham Baldwin Agricultural College               13
# 3  488031               Abraham Lincoln University                6
# 4  172866                          Academy College               27
#
#    Sector of institution  Degree-granting status  Institution size category  \
# 0                      2                       1                          2
# 1                      2                       1                          3
# 2                      1                       1                          2
# 3                      3                       1                          1
# 4                      3                       1                          1
#
#                  Institution (entity) name Institution name alias  \
# 0  A T Still University of Health Sciences                    NaN
# 1             Abilene Christian University                    NaN
# 2     Abraham Baldwin Agricultural College                   ABAC
# 3               Abraham Lincoln University                    NaN
# 4                          Academy College                    NaN
#
#      Street address or post office box         City  ...  \
# 0                      800 W Jefferson   Kirksville  ...
# 1                                  NaN      Abilene  ...
# 2                       2802 Moore Hwy       Tifton  ...
# 3  3530 Wilshire Boulevard  Suite 1430  Los Angeles  ...
# 4       1600 W. 82nd Street  Suite 100  Bloomington  ...
#
#   Undergraduate enrollment  Graduate enrollment Students receiving a PhD  \
# 0                      0.0               3723.0                      763
# 1                   3666.0               1479.0                        3
# 2                   3394.0                  0.0                        0
# 3                     30.0                167.0                       17
# 4                     65.0                  0.0                        0
#
#    Students receiving a MA  Students receiving a BA  Students receiving an AA  \
# 0                      283                        0                         0
# 1                      256                      743                         3
# 2                        0                      206                       389
# 3                        6                        2                         0
# 4                        0                        6                        16
#
#    Students receiving a Postbaccalaureate or Post-master's certificate  \
# 0                                                120
# 1                                                 11
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Students receiving a certificate of 1 but less than 4-years  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  4
#
#    Students receiving a certificate of less than 1-year  Unnamed: 24
# 0                                                  0             NaN
# 1                                                  1             NaN
# 2                                                  0             NaN
# 3                                                  0             NaN
# 4                                                 27             NaN
#
# [5 rows x 25 columns]

# %%
cols_to_replace = {
    'Street address or post office box': 'Address',
    'FIPS state code': 'FIPS state',
    'Fips County code': 'FIPS county',
    'Sector of institution': 'Sector'
}
    
data = data.rename(columns = cols_to_replace)
data.head()
# Out:
#    UnitID                         Institution Name  FIPS state  Sector  \
# 0  177834  A T Still University of Health Sciences          29       2
# 1  222178             Abilene Christian University          48       2
# 2  138558     Abraham Baldwin Agricultural College          13       1
# 3  488031               Abraham Lincoln University           6       3
# 4  172866                          Academy College          27       3
#
#    Degree-granting status  Institution size category  \
# 0                       1                          2
# 1                       1                          3
# 2                       1                          2
# 3                       1                          1
# 4                       1                          1
#
#                  Institution (entity) name Institution name alias  \
# 0  A T Still University of Health Sciences                    NaN
# 1             Abilene Christian University                    NaN
# 2     Abraham Baldwin Agricultural College                   ABAC
# 3               Abraham Lincoln University                    NaN
# 4                          Academy College                    NaN
#
#                                Address         City  ...  \
# 0                      800 W Jefferson   Kirksville  ...
# 1                                  NaN      Abilene  ...
# 2                       2802 Moore Hwy       Tifton  ...
# 3  3530 Wilshire Boulevard  Suite 1430  Los Angeles  ...
# 4       1600 W. 82nd Street  Suite 100  Bloomington  ...
#
#   Undergraduate enrollment  Graduate enrollment Students receiving a PhD  \
# 0                      0.0               3723.0                      763
# 1                   3666.0               1479.0                        3
# 2                   3394.0                  0.0                        0
# 3                     30.0                167.0                       17
# 4                     65.0                  0.0                        0
#
#    Students receiving a MA  Students receiving a BA  Students receiving an AA  \
# 0                      283                        0                         0
# 1                      256                      743                         3
# 2                        0                      206                       389
# 3                        6                        2                         0
# 4                        0                        6                        16
#
#    Students receiving a Postbaccalaureate or Post-master's certificate  \
# 0                                                120
# 1                                                 11
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Students receiving a certificate of 1 but less than 4-years  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  4
#
#    Students receiving a certificate of less than 1-year  Unnamed: 24
# 0                                                  0             NaN
# 1                                                  1             NaN
# 2                                                  0             NaN
# 3                                                  0             NaN
# 4                                                 27             NaN
#
# [5 rows x 25 columns]

# %%
data.head(2).T
# Out:
#                                                                                           0  \
# UnitID                                                                               177834
# Institution Name                                    A T Still University of Health Sciences
# FIPS state                                                                               29
# Sector                                                                                    2
# Degree-granting status                                                                    1
# Institution size category                                                                 2
# Institution (entity) name                           A T Still University of Health Sciences
# Institution name alias                                                                  NaN
# Address                                                                     800 W Jefferson
# City                                                                             Kirksville
# State abbreviation                                                                       MO
# FIPS county                                                                           29001
# County name                                                                    Adair County
# Longitude                                                                          -92.5892
# Latitude                                                                            40.1936
# Undergraduate enrollment                                                                  0
# Graduate enrollment                                                                    3723
# Students receiving a PhD                                                                763
# Students receiving a MA                                                                 283
# Students receiving a BA                                                                   0
# Students receiving an AA                                                                  0
# Students receiving a Postbaccalaureate or Post-...                                      120
# Students receiving a certificate of 1 but less ...                                        0
# Students receiving a certificate of less than 1...                                        0
# Unnamed: 24                                                                             NaN
#
#                                                                                1
# UnitID                                                                    222178
# Institution Name                                    Abilene Christian University
# FIPS state                                                                    48
# Sector                                                                         2
# Degree-granting status                                                         1
# Institution size category                                                      3
# Institution (entity) name                           Abilene Christian University
# Institution name alias                                                       NaN
# Address                                                                      NaN
# City                                                                     Abilene
# State abbreviation                                                            TX
# FIPS county                                                                48441
# County name                                                        Taylor County
# Longitude                                                               -99.7098
# Latitude                                                                 32.4689
# Undergraduate enrollment                                                    3666
# Graduate enrollment                                                         1479
# Students receiving a PhD                                                       3
# Students receiving a MA                                                      256
# Students receiving a BA                                                      743
# Students receiving an AA                                                       3
# Students receiving a Postbaccalaureate or Post-...                            11
# Students receiving a certificate of 1 but less ...                             0
# Students receiving a certificate of less than 1...                             1
# Unnamed: 24                                                                  NaN

# %%
data = data.drop(columns = ['Degree-granting status', 'Institution name alias', "Students receiving a Postbaccalaureate or Post-master's certificate", 'Students receiving a certificate of 1 but less than 4-years', 'Students receiving a certificate of less than 1-year',  'Unnamed: 24'])

# %%
data.head(2).T
# Out:
#                                                                  0  \
# UnitID                                                      177834
# Institution Name           A T Still University of Health Sciences
# FIPS state                                                      29
# Sector                                                           2
# Institution size category                                        2
# Institution (entity) name  A T Still University of Health Sciences
# Address                                            800 W Jefferson
# City                                                    Kirksville
# State abbreviation                                              MO
# FIPS county                                                  29001
# County name                                           Adair County
# Longitude                                                 -92.5892
# Latitude                                                   40.1936
# Undergraduate enrollment                                         0
# Graduate enrollment                                           3723
# Students receiving a PhD                                       763
# Students receiving a MA                                        283
# Students receiving a BA                                          0
# Students receiving an AA                                         0
#
#                                                       1
# UnitID                                           222178
# Institution Name           Abilene Christian University
# FIPS state                                           48
# Sector                                                2
# Institution size category                             3
# Institution (entity) name  Abilene Christian University
# Address                                             NaN
# City                                            Abilene
# State abbreviation                                   TX
# FIPS county                                       48441
# County name                               Taylor County
# Longitude                                      -99.7098
# Latitude                                        32.4689
# Undergraduate enrollment                           3666
# Graduate enrollment                                1479
# Students receiving a PhD                              3
# Students receiving a MA                             256
# Students receiving a BA                             743
# Students receiving an AA                              3

# %%
labels = pd.read_csv("../data/external/ValueLabels_10-3-2019---695.csv")

# %%
labels[labels['VariableName'].str.contains("Sector")]
# Out:
#                        VariableName Value  \
# 102  Sector of institution (HD2017)     1
# 103  Sector of institution (HD2017)     2
# 104  Sector of institution (HD2017)     3
#
#                                   ValueLabel
# 102                  Public, 4-year or above
# 103  Private not-for-profit, 4-year or above
# 104      Private for-profit, 4-year or above

# %%
size_cat = {
    1: 'Under 1,000',
    2: '1,000 - 4,999',
    3: '5,000 - 9,999',
    4: '10,000 - 19,999', 
    5: '20,000 and above',
}
sector_cat = {
    1: "Public",
    2: "PnP",
    3: "PfP",
}

# %%
data['Sector'] = data['Sector'].map(sector_cat)

# %%
data['Institution size category'] = data['Institution size category'].map(size_cat)

# %%
data = data.rename(columns = {"Institution size category": "Size"})

# %%
data.head()
# Out:
#    UnitID                         Institution Name  FIPS state  Sector  \
# 0  177834  A T Still University of Health Sciences          29     PnP
# 1  222178             Abilene Christian University          48     PnP
# 2  138558     Abraham Baldwin Agricultural College          13  Public
# 3  488031               Abraham Lincoln University           6     PfP
# 4  172866                          Academy College          27     PfP
#
#             Size                Institution (entity) name  \
# 0  1,000 - 4,999  A T Still University of Health Sciences
# 1  5,000 - 9,999             Abilene Christian University
# 2  1,000 - 4,999     Abraham Baldwin Agricultural College
# 3    Under 1,000               Abraham Lincoln University
# 4    Under 1,000                          Academy College
#
#                                Address         City State abbreviation  \
# 0                      800 W Jefferson   Kirksville                 MO
# 1                                  NaN      Abilene                 TX
# 2                       2802 Moore Hwy       Tifton                 GA
# 3  3530 Wilshire Boulevard  Suite 1430  Los Angeles                 CA
# 4       1600 W. 82nd Street  Suite 100  Bloomington                 MN
#
#    FIPS county         County name   Longitude   Latitude  \
# 0        29001        Adair County  -92.589183  40.193648
# 1        48441       Taylor County  -99.709797  32.468943
# 2        13277         Tift County  -83.528281  31.481889
# 3         6037  Los Angeles County -118.301362  34.061398
# 4        27053     Hennepin County  -93.299809  44.855722
#
#    Undergraduate enrollment  Graduate enrollment  Students receiving a PhD  \
# 0                       0.0               3723.0                       763
# 1                    3666.0               1479.0                         3
# 2                    3394.0                  0.0                         0
# 3                      30.0                167.0                        17
# 4                      65.0                  0.0                         0
#
#    Students receiving a MA  Students receiving a BA  Students receiving an AA
# 0                      283                        0                         0
# 1                      256                      743                         3
# 2                        0                      206                       389
# 3                        6                        2                         0
# 4                        0                        6                        16

# %%
data.to_csv("../data/processed/colleges_in_US.csv", encoding = 'utf-8', index = False)
